# %% [markdown]
# # Min Clean Each Dataset and Combine

# %%
import pandas as pd
from pathlib import Path
import re

def clean_text(text):
    """
    Clean the input text by removing HTML tags and unwanted characters.
    This function converts the input to a string, removes any HTML tags,
    filters out characters that are not alphanumeric, punctuation (.,!?), 
    or whitespace, and trims leading and trailing whitespace.

    Args:
        text (str): The text to be cleaned.
    Returns:
        str: The cleaned text.
    """
    # Remove HTML tags from the text
    text = re.sub(r"<.*?>", "", str(text))
    # Remove characters that are not letters, numbers, punctuation, or whitespace
    text = re.sub(r"[^a-zA-Z0-9.,!?\s]", " ", text)
    #colapse 2 white spaces to one
    text = re.sub(r'\s{2,}', ' ', text)
    # Return the cleaned text with whitespace trimmed
    return text.strip()

# if __name__ == '__main__':
#     df_medquad = pd.read_csv("data/processed/medquad.csv")
#     df_icliniq = pd.read_csv("data/processed/icliniq.csv")

#     # Merge
#     df_combined = pd.concat([df_medquad, df_icliniq], ignore_index=True)

    

#     # Clean
#     df_combined["question"] = df_combined["question"].apply(clean_text)
#     df_combined["answer"]   = df_combined["answer"].apply(clean_text)

#     # Remove duplicates
#     df_combined.drop_duplicates(subset=["question","answer"], inplace=True)

#     df_combined.to_csv("data/processed/qa_master.csv", index=False)

# %%
df_medquad = pd.read_csv("../data/processed/medquad.csv")
df_icliniq = pd.read_csv("../data/processed/icliniq.csv")

# %% [markdown]
# ### 1. MEDQUAD

# %%
df_medquad = df_medquad.drop(['url', 'document_id', 'semantic_group'], axis=1)
df_medquad.head()
# Out:
#   source                         focus synonyms  pid            qtype  \
# 0    GHR  keratoderma with woolly hair     KWWH    1      information
# 1    GHR  keratoderma with woolly hair     KWWH    2        frequency
# 2    GHR  keratoderma with woolly hair     KWWH    3  genetic changes
# 3    GHR  keratoderma with woolly hair     KWWH    4      inheritance
# 4    GHR  keratoderma with woolly hair     KWWH    5        treatment
#
#                                             question  \
# 0       What is (are) keratoderma with woolly hair ?
# 1  How many people are affected by keratoderma wi...
# 2  What are the genetic changes related to kerato...
# 3        Is keratoderma with woolly hair inherited ?
# 4  What are the treatments for keratoderma with w...
#
#                                               answer
# 0  Keratoderma with woolly hair is a group of rel...
# 1  Keratoderma with woolly hair is rare; its prev...
# 2  Mutations in the JUP, DSP, DSC2, and KANK2 gen...
# 3  Most cases of keratoderma with woolly hair hav...
# 4  These resources address the diagnosis or manag...

# %%
print(df_medquad.isna().sum().reset_index())
# Out:
#       index     0
# 0    source     0
# 1     focus    14
# 2  synonyms  5518
# 3       pid     0
# 4     qtype     0
# 5  question     0
# 6    answer     5

# %%
# ddropping columns where answers are null
df_medquad.dropna(subset=['answer'], inplace=True)

# %%
df_medquad['context'] =  df_medquad['synonyms'].fillna('')+ ' '+df_medquad['focus'].fillna('')+' ' + df_medquad['question'].fillna('')
df_medquad['Dataset'] = 'MedQuad'

df_medquad = df_medquad[['Dataset','focus','synonyms', 'qtype','question', 'context', 'answer' ]]
df_medquad.head()
# Out:
#    Dataset                         focus synonyms            qtype  \
# 0  MedQuad  keratoderma with woolly hair     KWWH      information
# 1  MedQuad  keratoderma with woolly hair     KWWH        frequency
# 2  MedQuad  keratoderma with woolly hair     KWWH  genetic changes
# 3  MedQuad  keratoderma with woolly hair     KWWH      inheritance
# 4  MedQuad  keratoderma with woolly hair     KWWH        treatment
#
#                                             question  \
# 0       What is (are) keratoderma with woolly hair ?
# 1  How many people are affected by keratoderma wi...
# 2  What are the genetic changes related to kerato...
# 3        Is keratoderma with woolly hair inherited ?
# 4  What are the treatments for keratoderma with w...
#
#                                              context  \
# 0  KWWH keratoderma with woolly hair What is (are...
# 1  KWWH keratoderma with woolly hair How many peo...
# 2  KWWH keratoderma with woolly hair What are the...
# 3  KWWH keratoderma with woolly hair Is keratoder...
# 4  KWWH keratoderma with woolly hair What are the...
#
#                                               answer
# 0  Keratoderma with woolly hair is a group of rel...
# 1  Keratoderma with woolly hair is rare; its prev...
# 2  Mutations in the JUP, DSP, DSC2, and KANK2 gen...
# 3  Most cases of keratoderma with woolly hair hav...
# 4  These resources address the diagnosis or manag...

# %%
df_medquad.focus.unique()
# Out:
# array(['keratoderma with woolly hair', 'Knobloch syndrome', 'coloboma',
#        ..., 'High Blood Pressure and Kidney Disease',
#        'What I need to know about Cirrhosis',
#        '4 Steps to Manage Your Diabetes for Life'],
#       shape=(5126,), dtype=object)

# %% [markdown]
# ## 2. iCliniq

# %%
df_icliniq.head()
# Out:
#                      Speciality  \
# 0              Medical oncology
# 1                   Dermatology
# 2        Otolaryngology (E.N.T)
# 3      Medical Gastroenterology
# 4  Pulmonology (Asthma Doctors)
#
#                                                Title  \
# 0  What are effective therapies for metastatic br...
# 1                               How does HIV spread?
# 2  Can recurrent hoarseness without GERD indicate...
# 3                 Is long-term Pantocid-IT use safe?
# 4        Can type 2 diabetes resolve after delivery?
#
#                                             Abstract  \
# 0  Metastatic breast cancer occurs when cancer sp...
# 1  HIV spreads by certain body fluids from an inf...
# 2  Recurrent hoarseness may result from vocal str...
# 3  Long-term use of Pantocid-IT may cause nutrien...
# 4  After giving birth, a person with type 1 diabe...
#
#                                             Question  \
# 0  Hello doctor,\nMy mother was diagnosed with st...
# 1  Hello doctor,Last night I went for dinner and ...
# 2  Hi doctor,I am a 59-year-old male and a nonsmo...
# 3  Hi doctor,\nI am a 35-year-old male. My height...
# 4  Hi doctor,My sister delivered a baby one month...
#
#                                               Answer
# 0  Hello,\nWelcome to icliniq.com.\nI can underst...
# 1  Hello,\nWelcome to icliniq.com.\nI read your q...
# 2  Hi,\nWelcome to icliniq.com.\nI have read your...
# 3  Hi,\nWelcome to icliniq.com.\nI have read your...
# 4  Hi,\nWelcome to icliniq.com.\nI have gone thro...

# %%
df_icliniq.Abstract
# Out:
# 0        Metastatic breast cancer occurs when cancer sp...
# 1        HIV spreads by certain body fluids from an inf...
# 2        Recurrent hoarseness may result from vocal str...
# 3        Long-term use of Pantocid-IT may cause nutrien...
# 4        After giving birth, a person with type 1 diabe...
#                                ...
# 48452                                                  NaN
# 48453                                                  NaN
# 48454                                                  NaN
# 48455                                                  NaN
# 48456                                                  NaN
# Name: Abstract, Length: 48457, dtype: object

# %%
df_icliniq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48457 entries, 0 to 48456
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Speciality  48343 non-null  object
#  1   Title       48457 non-null  object
#  2   Abstract    43343 non-null  object
#  3   Question    48457 non-null  object
#  4   Answer      48457 non-null  object
# dtypes: object(5)
# memory usage: 1.8+ MB

# %%
df_icliniq['context'] = df_icliniq['Abstract'].fillna('')+' ' + df_icliniq['Question'].fillna('')
df_icliniq = df_icliniq[['Speciality', 'Title', 'context', 'Answer']]
df_icliniq['Dataset'] = 'iCliniQ'

df_icliniq.rename(columns={
    "Speciality": "speciality",
    "Title": "question",
    "Answer": "answer"
}, inplace=True)

df_icliniq.head()
# Out:
#                      speciality  \
# 0              Medical oncology
# 1                   Dermatology
# 2        Otolaryngology (E.N.T)
# 3      Medical Gastroenterology
# 4  Pulmonology (Asthma Doctors)
#
#                                             question  \
# 0  What are effective therapies for metastatic br...
# 1                               How does HIV spread?
# 2  Can recurrent hoarseness without GERD indicate...
# 3                 Is long-term Pantocid-IT use safe?
# 4        Can type 2 diabetes resolve after delivery?
#
#                                              context  \
# 0  Metastatic breast cancer occurs when cancer sp...
# 1  HIV spreads by certain body fluids from an inf...
# 2  Recurrent hoarseness may result from vocal str...
# 3  Long-term use of Pantocid-IT may cause nutrien...
# 4  After giving birth, a person with type 1 diabe...
#
#                                               answer  Dataset
# 0  Hello,\nWelcome to icliniq.com.\nI can underst...  iCliniQ
# 1  Hello,\nWelcome to icliniq.com.\nI read your q...  iCliniQ
# 2  Hi,\nWelcome to icliniq.com.\nI have read your...  iCliniQ
# 3  Hi,\nWelcome to icliniq.com.\nI have read your...  iCliniQ
# 4  Hi,\nWelcome to icliniq.com.\nI have gone thro...  iCliniQ

# %% [markdown]
# ## Combine

# %%
df_combined = pd.concat([df_medquad, df_icliniq], ignore_index=True)
df_combined
# Out:
#        Dataset                         focus synonyms            qtype  \
# 0      MedQuad  keratoderma with woolly hair     KWWH      information
# 1      MedQuad  keratoderma with woolly hair     KWWH        frequency
# 2      MedQuad  keratoderma with woolly hair     KWWH  genetic changes
# 3      MedQuad  keratoderma with woolly hair     KWWH      inheritance
# 4      MedQuad  keratoderma with woolly hair     KWWH        treatment
# ...        ...                           ...      ...              ...
# 64859  iCliniQ                           NaN      NaN              NaN
# 64860  iCliniQ                           NaN      NaN              NaN
# 64861  iCliniQ                           NaN      NaN              NaN
# 64862  iCliniQ                           NaN      NaN              NaN
# 64863  iCliniQ                           NaN      NaN              NaN
#
#                                                 question  \
# 0           What is (are) keratoderma with woolly hair ?
# 1      How many people are affected by keratoderma wi...
# 2      What are the genetic changes related to kerato...
# 3            Is keratoderma with woolly hair inherited ?
# 4      What are the treatments for keratoderma with w...
# ...                                                  ...
# 64859  I am not gaining weight. Please guide me if I ...
# 64860     Do I need treatment for premature ejaculation?
# 64861  I had unprotected sex. What are my chances of ...
# 64862          How many days after HIV do rashes appear?
# 64863  What are the treatment options for Internal He...
#
#                                                  context  \
# 0      KWWH keratoderma with woolly hair What is (are...
# 1      KWWH keratoderma with woolly hair How many peo...
# 2      KWWH keratoderma with woolly hair What are the...
# 3      KWWH keratoderma with woolly hair Is keratoder...
# 4      KWWH keratoderma with woolly hair What are the...
# ...                                                  ...
# 64859   Hi doctor,\nI am 24 years old male. For the p...
# 64860   Hello doctor,\nI am 37 years old, a gynecolog...
# 64861   Hello doctor,\nI had unprotected sex with my ...
# 64862   Hello doctor,\n15 days back, I met a girl and...
# 64863   Hello doctor,\nI could feel a lump near my an...
#
#                                                   answer  \
# 0      Keratoderma with woolly hair is a group of rel...
# 1      Keratoderma with woolly hair is rare; its prev...
# 2      Mutations in the JUP, DSP, DSC2, and KANK2 gen...
# 3      Most cases of keratoderma with woolly hair hav...
# 4      These resources address the diagnosis or manag...
# ...                                                  ...
# 64859  Hello,Welcome to icliniq.com.First of all, che...
# 64860  Hello,\nWelcome to icliniq.com.\nNo, it is not...
# 64861  Hi,\nWelcome to icliniq.com.\nPlease do not be...
# 64862  Hello,\nWelcome to icliniq.com.\n\nA rash is a...
# 64863  Hi,\nWelcome to icliniq.com.\nIn this type of ...
#
#                       speciality
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 64859                  Neurology
# 64860                 Cardiology
# 64861  Obstetrics and Gynecology
# 64862                Dermatology
# 64863   Medical Gastroenterology
#
# [64864 rows x 8 columns]

# %%
df_combined = df_combined.fillna('')

# %%
df_combined["question"].apply(clean_text)
# Out:
# 0               What is are keratoderma with woolly hair ?
# 1        How many people are affected by keratoderma wi...
# 2        What are the genetic changes related to kerato...
# 3              Is keratoderma with woolly hair inherited ?
# 4        What are the treatments for keratoderma with w...
#                                ...
# 64859    I am not gaining weight. Please guide me if I ...
# 64860       Do I need treatment for premature ejaculation?
# 64861    I had unprotected sex. What are my chances of ...
# 64862            How many days after HIV do rashes appear?
# 64863    What are the treatment options for Internal He...
# Name: question, Length: 64798, dtype: object

# %%
df_combined
# Out:
#        Dataset                         focus synonyms            qtype  \
# 0      MedQuad  keratoderma with woolly hair     KWWH      information
# 1      MedQuad  keratoderma with woolly hair     KWWH        frequency
# 2      MedQuad  keratoderma with woolly hair     KWWH  genetic changes
# 3      MedQuad  keratoderma with woolly hair     KWWH      inheritance
# 4      MedQuad  keratoderma with woolly hair     KWWH        treatment
# ...        ...                           ...      ...              ...
# 64859  iCliniQ
# 64860  iCliniQ
# 64861  iCliniQ
# 64862  iCliniQ
# 64863  iCliniQ
#
#                                                 question  \
# 0             What is are keratoderma with woolly hair ?
# 1      How many people are affected by keratoderma wi...
# 2      What are the genetic changes related to kerato...
# 3            Is keratoderma with woolly hair inherited ?
# 4      What are the treatments for keratoderma with w...
# ...                                                  ...
# 64859  I am not gaining weight. Please guide me if I ...
# 64860     Do I need treatment for premature ejaculation?
# 64861  I had unprotected sex. What are my chances of ...
# 64862          How many days after HIV do rashes appear?
# 64863  What are the treatment options for Internal He...
#
#                                                  context  \
# 0      KWWH keratoderma with woolly hair What is are ...
# 1      KWWH keratoderma with woolly hair How many peo...
# 2      KWWH keratoderma with woolly hair What are the...
# 3      KWWH keratoderma with woolly hair Is keratoder...
# 4      KWWH keratoderma with woolly hair What are the...
# ...                                                  ...
# 64859  Hi doctor,\nI am 24 years old male. For the pa...
# 64860  Hello doctor,\nI am 37 years old, a gynecologi...
# 64861  Hello doctor,\nI had unprotected sex with my b...
# 64862  Hello doctor,\n15 days back, I met a girl and ...
# 64863  Hello doctor,\nI could feel a lump near my anu...
#
#                                                   answer  \
# 0      Keratoderma with woolly hair is a group of rel...
# 1      Keratoderma with woolly hair is rare its preva...
# 2      Mutations in the JUP, DSP, DSC2, and KANK2 gen...
# 3      Most cases of keratoderma with woolly hair hav...
# 4      These resources address the diagnosis or manag...
# ...                                                  ...
# 64859  Hello,Welcome to icliniq.com.First of all, che...
# 64860  Hello,\nWelcome to icliniq.com.\nNo, it is not...
# 64861  Hi,\nWelcome to icliniq.com.\nPlease do not be...
# 64862  Hello,\nWelcome to icliniq.com. A rash is a ve...
# 64863  Hi,\nWelcome to icliniq.com.\nIn this type of ...
#
#                       speciality
# 0
# 1
# 2
# 3
# 4
# ...                          ...
# 64859                  Neurology
# 64860                 Cardiology
# 64861  Obstetrics and Gynecology
# 64862                Dermatology
# 64863   Medical Gastroenterology
#
# [64798 rows x 8 columns]

# %%
# ----- Clean Text Columns -----
# Apply the clean_text function to remove unwanted characters from text columns
df_combined["question"] = df_combined["question"].apply(clean_text)
df_combined["answer"]   = df_combined["answer"].apply(clean_text)
df_combined["context"]  = df_combined["context"].apply(clean_text)

# %%
# ----- Remove Duplicates -----
# Drop duplicate rows based on the combination of 'question' and 'answer'
df_combined.drop_duplicates(subset=["question", "answer"], inplace=True)

# %%
df_combined.to_csv("../data/processed/qa_master.csv", index=False)

# %%
import airflow
print("Airflow is installed, version:", airflow.__version__)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniconda/base/envs/MediMaven/lib/python3.13/site-packages/airflow/settings.py:55
#      54     else:
# ---> 55         TIMEZONE = pendulum.tz.timezone(tz)
#      56 except Exception:
#
# TypeError: 'module' object is not callable
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[169], line 1
# ----> 1 import airflow
#       2 print("Airflow is installed, version:", airflow.__version__)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/MediMaven/lib/python3.13/site-packages/airflow/__init__.py:52
#      43     patch_all()
#      45 # The configuration module initializes and validates the conf object as a side effect the first
#      46 # time it is imported. If it is not imported before importing the settings module, the conf
#      47 # object will then be initted/validated as a side effect of it being imported in settings,
#    (...)
#      50 # those functions likely import settings).
#      51 # configuration is therefore initted early here, simply by importing it.
# ---> 52 from airflow import configuration, settings
#      54 __all__ = ["__version__", "login", "DAG", "PY36", "PY37", "PY38", "PY39", "PY310", "XComArg"]
#      56 # Make `airflow` an namespace package, supporting installing
#      57 # airflow.providers.* in different locations (i.e. one in site, and one in user
#      58 # lib.)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/MediMaven/lib/python3.13/site-packages/airflow/configuration.py:2340
#    2337 WEBSERVER_CONFIG = ""  # Set by initialize_config
#    2339 conf: AirflowConfigParser = initialize_config()
# -> 2340 secrets_backend_list = initialize_secrets_backends()
#    2341 conf.validate()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/MediMaven/lib/python3.13/site-packages/airflow/configuration.py:2254, in initialize_secrets_backends()
#    2251     backend_list.append(custom_secret_backend)
#    2253 for class_name in DEFAULT_SECRETS_SEARCH_PATH:
# -> 2254     secrets_backend_cls = import_string(class_name)
#    2255     backend_list.append(secrets_backend_cls())
#    2257 return backend_list
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/MediMaven/lib/python3.13/site-packages/airflow/utils/module_loading.py:37, in import_string(dotted_path)
#      34 except ValueError:
#      35     raise ImportError(f"{dotted_path} doesn't look like a module path")
# ---> 37 module = import_module(module_path)
#      39 try:
#      40     return getattr(module, class_name)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/MediMaven/lib/python3.13/importlib/__init__.py:88, in import_module(name, package)
#      86             break
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/MediMaven/lib/python3.13/site-packages/airflow/secrets/metastore.py:29
#      27 from airflow.exceptions import RemovedInAirflow3Warning
#      28 from airflow.secrets import BaseSecretsBackend
# ---> 29 from airflow.utils.session import NEW_SESSION, provide_session
#      31 if TYPE_CHECKING:
#      32     from airflow.models.connection import Connection
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/MediMaven/lib/python3.13/site-packages/airflow/utils/session.py:24
#      21 from inspect import signature
#      22 from typing import Callable, Generator, TypeVar, cast
# ---> 24 from airflow import settings
#      25 from airflow.typing_compat import ParamSpec
#      28 @contextlib.contextmanager
#      29 def create_session() -> Generator[settings.SASession, None, None]:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/MediMaven/lib/python3.13/site-packages/airflow/settings.py:57
#      55         TIMEZONE = pendulum.tz.timezone(tz)
#      56 except Exception:
# ---> 57     TIMEZONE = pendulum.tz.timezone("UTC")
#      59 log.info("Configured default timezone %s", TIMEZONE)
#      62 HEADER = "\n".join(
#      63     [
#      64         r"  ____________       _____________",
#    (...)
#      69     ]
#      70 )
#
# TypeError: 'module' object is not callable
